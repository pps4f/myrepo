# %%
# %sql
select * from hive_metastore.default.orders_raw
-- Jasons's comment

# %%
# %sql
select sum(quantity) from hive_metastore.default.orders_raw

# %%
# %sql
select * from hive_metastore.default.trip_avg
-- Added David's comment here
